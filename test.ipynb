# %%
import json
import pprint
import pandas as pd

# %%
with open("./Raw_data/2018/201800000") as file: 
    data = json.load(file)  # Parse the JSON content into a Python dictionary
    # pprint.pprint(data.get('abstracts-retrieval-response').get('item'))  # Access the key
    pprint.pprint(data.get('abstracts-retrieval-response').get('item').get('bibrecord').get('tail'))  # Access the key
# Out:
# {'bibliography': {'@refcount': '76',
#                   'reference': [{'@id': '1',
#                                  'ref-fulltext': 'Winslow CE. The untilled '
#                                                  'fields of public health. '
#                                                  'Science. 1920;51:23-33.',
#                                  'ref-info': {'ref-authors': {'author': [{'@_fa': 'true',
#                                                                           '@seq': '1',
#                                                                           'ce:indexed-name': 'Winslow '
#                                                                                              'C.E.',
#                                                                           'ce:initials': 'C.E.',
#                                                                           'ce:surname': 'Winslow'}]},
#                                               'ref-publicationyear': {'@first': '1920'},
#                                               'ref-sourcetitle': 'Science.',
#                                               'ref-title': {'ref-titletext': 'The '
#                                                                              'untilled '
#                                                                              'fields '
#                                                                              'of '
#                                                                              'public '
#                                                                              'health'},
#                                               'ref-volisspag': {'pagerange': {'@first': '23',
#                                                                               '@last': '33'},
#                                                                 'voliss': {'@volume': '51'}},
#                                               'refd-itemidlist': {'itemid': {'$': '0002667983',
#                                                                              '@idtype': 'SGR'}}}},
#                                 {'@id': '2',
#                                  'ref-fulltext': 'Institute of Medicine '
#                                                  '(U.S.). Committee for the '
#                                                  'Study of the Future of '
#                                                  'Public Health. The future of '
#                                                  'public health, vol. xii. '
#                                                  'Washington, D.C: National '
#                                                  'Academy Press; 1988. p. 225.',
#                                  'ref-info': {'ref-authors': {'collaboration': {'@seq': '1',
#                                                                                 'ce:indexed-name': 'Institute '
#                                                                                                    'of '
#                                                                                                    'Medicine '
#                                                                                                    '(U.S.)',
#                                                                                 'ce:text': 'Institute '
#                                                                                            'of '
#                                                                                            'Medicine '
#                                                                                            '(U.S.)'}},
#                                               'ref-publicationyear': {'@first': '1988'},
#                                               'ref-sourcetitle': 'The future '
#                                                                  'of public '
#                                                                  'health',
#                                               'ref-text': 'Washington, D.C: '
#                                                           'National Academy '
#                                                           'Press',
#                                               'ref-title': {'ref-titletext': 'Committee '
#                                                                              'for '
#                                                                              'the '
#                                                                              'Study '
#                                                                              'of '
#                                                                              'the '
#                                                                              'Future '
#                                                                              'of '
#                                                                              'Public '
#                                                                              'Health'},
#                                               'ref-volisspag': {'pagerange': {'@first': '225'},
#                                                                 'voliss': {'@volume': '12'}},
#                                               'refd-itemidlist': {'itemid': {'$': '33750367977',
#                                                                              '@idtype': 'SGR'}}}},
#                                 {'@id': '3',
#                                  'ref-fulltext': 'Heggenhougen K, Quah SR. '
#                                                  'International encyclopedia '
#                                                  'of public health. Oxford: '
#                                                  'Academic; 2008.',
#                                  'ref-info': {'ref-authors': {'author': [{'@_fa': 'true',
#                                                                           '@seq': '1',
#                                                                           'ce:indexed-name': 'Heggenhougen '
#                                                                                              'K.',
#                                                                           'ce:initials': 'K.',
#                                                                           'ce:surname': 'Heggenhougen'},
#                                                                          {'@_fa': 'true',
#                                                                           '@seq': '2',
#                                                                           'ce:indexed-name': 'Quah '
#                                                                                              'S.R.',
#                                                                           'ce:initials': 'S.R.',
#                                                                           'ce:surname': 'Quah'}]},
#                                               'ref-publicationyear': {'@first': '2008'},
#                                               'ref-sourcetitle': 'International '
#                                                                  'encyclopedia '
#                                                                  'of public '
#                                                                  'health.',
#                                               'ref-text': 'Oxford: Academic',
#                                               'refd-itemidlist': {'itemid': {'$': '85013970385',
#                                                                              '@idtype': 'SGR'}}}},
#                                 {'@id': '4',
#                                  'ref-fulltext': 'Kirch W. Encyclopedia of '
#                                                  'public health. New '
#                                                  'York:Springer; 2008.',
#                                  'ref-info': {'ref-authors': {'author': [{'@_fa': 'true',
#                                                                           '@seq': '1',
#                                                                           'ce:indexed-name': 'Kirch '
#                                                                                              'W.',
#                                                                           'ce:initials': 'W.',
#                                                                           'ce:surname': 'Kirch'}]},
#                                               'ref-publicationyear': {'@first': '2008'},
#                                               'ref-sourcetitle': 'Encyclopedia '
#                                                                  'of public '
#                                                                  'health.',
#                                               'ref-text': 'New York:Springer',
#                                               'refd-itemidlist': {'itemid': {'$': '77953026614',
#                                                                              '@idtype': 'SGR'}}}},
#                                 {'@id': '5',
#                                  'ref-fulltext': 'Definition of Public health '
#                                                  '2010 [cited 2010 December '
#                                                  '08]. Available from: '
#                                                  'http://www.medterms. '
#                                                  'com/script/main/art.asp?articlekey=5120.',
#                                  'ref-info': {'ref-publicationyear': {'@first': '2010'},
#                                               'ref-sourcetitle': 'Definition '
#                                                                  'of Public '
#                                                                  'health',
#                                               'ref-text': 'cited 2010 December '
#                                                           '08]. Available from',
#                                               'ref-website': {'ce:e-address': {'$': 'http://www.medterms.com/script/main/art.asp?articlekey=5120',
#                                                                                '@type': 'email'}},
#                                               'refd-itemidlist': {'itemid': {'$': '85078067388',
#                                                                              '@idtype': 'SGR'}}}},
#                                 {'@id': '6',
#                                  'ref-fulltext': 'Public health 2010 [cited '
#                                                  '2010 December 08]. Available '
#                                                  'from: '
#                                                  'http://www.britannica.com/ '
#                                                  'EBchecked/topic/482384/public-health.',
#                                  'ref-info': {'ref-sourcetitle': 'Public '
#                                                                  'health 2010',
#                                               'ref-text': 'cited 2010 December '
#                                                           '08]. Available from',
#                                               'ref-website': {'ce:e-address': {'$': 'http://www.britannica.com/EBchecked/topic/482384/public-health',
#                                                                                '@type': 'email'}},
#                                               'refd-itemidlist': {'itemid': {'$': '84929049679',
#                                                                              '@idtype': 'SGR'}}}},
#                                 {'@id': '7',
#                                  'ref-fulltext': 'Public health: McGraw-Hill; '
#                                                  '2010. [Cited 2010 December '
#                                                  '08] '
#                                                  'http://www.accessscience.com/.',
#                                  'ref-info': {'ref-publicationyear': {'@first': '2010'},
#                                               'ref-sourcetitle': 'Public '
#                                                                  'health',
#                                               'ref-text': 'McGraw-Hill, Cited '
#                                                           '2010 December 08',
#                                               'ref-website': {'ce:e-address': {'$': 'http://www.accessscience.com/',
#                                                                                '@type': 'email'}},
#                                               'refd-itemidlist': {'itemid': {'$': '84858813345',
#                                                                              '@idtype': 'SGR'}}}},
#                                 {'@id': '8',
#                                  'ref-fulltext': 'Breslow L. Encyclopedia of '
#                                                  'public health. New '
#                                                  'York:Macmillan Reference '
#                                                  'USA/Gale Group Thomson '
#                                                  'Learning; 2002.',
#                                  'ref-info': {'ref-authors': {'author': [{'@_fa': 'true',
#                                                                           '@seq': '1',
#                                                                           'ce:indexed-name': 'Breslow '
#                                                                                              'L.',
#                                                                           'ce:initials': 'L.',
#                                                                           'ce:surname': 'Breslow'}]},
#                                               'ref-publicationyear': {'@first': '2002'},
#                                               'ref-sourcetitle': 'Encyclopedia '
#                                                                  'of public '
#                                                                  'health.',
#                                               'ref-text': 'New York:Macmillan '
#                                                           'Reference USA/Gale '
#                                                           'Group Thomson '
#                                                           'Learning',
#                                               'refd-itemidlist': {'itemid': {'$': '33748416777',
#                                                                              '@idtype': 'SGR'}}}},
#                                 {'@id': '9',
#                                  'ref-fulltext': 'Public health 2010 [cited '
#                                                  '2010 December 08]. Available '
#                                                  'from: '
#                                                  'http://en.wikipedia.org/wiki/ '
#                                                  'Public_health.',
#                                  'ref-info': {'ref-publicationyear': {'@first': '2010'},
#                                               'ref-sourcetitle': 'Public '
#                                                                  'health',
#                                               'ref-text': 'cited 2010 December '
#                                                           '08]. Available from',
#                                               'ref-website': {'ce:e-address': {'$': 'http://en.wikipedia.org/wiki/Public_health',
#                                                                                '@type': 'email'}},
#                                               'refd-itemidlist': {'itemid': {'$': '84858813345',
#                                                                              '@idtype': 'SGR'}}}},
#                                 {'@id': '10',
#                                  'ref-fulltext': 'Mollura DJ, Carrino JA, '
#                                                  'Matuszak DL, et al. Bridging '
#                                                  'radiology and public health: '
#                                                  'the emerging field of '
#                                                  'radiologic public health '
#                                                  'informatics. J Am Coll '
#                                                  'Radiol. 2008;5:174-81.',
#                                  'ref-info': {'ref-authors': {'author': [{'@_fa': 'true',
#                                                                           '@seq': '1',
#                                                                           'ce:indexed-name': 'Mollura '
#                                                                                              'D.J.',
#                                                                           'ce:initials': 'D.J.',
#                                                                           'ce:surname': 'Mollura'},
#                                                                          {'@_fa': 'true',
#                                                                           '@seq': '2',
#                                                                           'ce:indexed-name': 'Carrino '
#                                                                                              'J.A.',
#                                                                           'ce:initials': 'J.A.',
#                                                                           'ce:surname': 'Carrino'},
#                                                                          {'@_fa': 'true',
#                                                                           '@seq': '3',
#                                                                           'ce:indexed-name': 'Matuszak '
#                                                                                              'D.L.',
#                                                                           'ce:initials': 'D.L.',
#                                                                           'ce:surname': 'Matuszak'}],
#                                                               'et-al': None},
#                                               'ref-publicationyear': {'@first': '2008'},
#                                               'ref-sourcetitle': 'J Am Coll '
#                                                                  'Radiol.',
#                                               'ref-title': {'ref-titletext': 'Bridging '
#                                                                              'radiology '
#                                                                              'and '
#                                                                              'public '
#                                                                              'health: '
#                                                                              'the '
#                                                                              'emerging '
#                                                                              'field '
#                                                                              'of '
#                                                                              'radiologic '
#                                                                              'public '
#                                                                              'health '
#                                                                              'informatics'},
#                                               'ref-volisspag': {'pagerange': {'@first': '174',
#                                                                               '@last': '181'},
#                                                                 'voliss': {'@volume': '5'}},
#                                               'refd-itemidlist': {'itemid': {'$': '39749120724',
#                                                                              '@idtype': 'SGR'}}}},
#                                 {'@id': '11',
#                                  'ref-fulltext': 'Hillman BJ. Radiology and '
#                                                  'public health. J Am Coll '
#                                                  'Radiol. 2008;5:155.',
#                                  'ref-info': {'ref-authors': {'author': [{'@_fa': 'true',
#                                                                           '@seq': '1',
#                                                                           'ce:indexed-name': 'Hillman '
#                                                                                              'B.J.',
#                                                                           'ce:initials': 'B.J.',
#                                                                           'ce:surname': 'Hillman'}]},
#                                               'ref-publicationyear': {'@first': '2008'},
#                                               'ref-sourcetitle': 'J Am Coll '
#                                                                  'Radiol.',
#                                               'ref-title': {'ref-titletext': 'Radiology '
#                                                                              'and '
#                                                                              'public '
#                                                                              'health'},
#                                               'ref-volisspag': {'pagerange': {'@first': '155'},
#                                                                 'voliss': {'@volume': '5'}},
#                                               'refd-itemidlist': {'itemid': {'$': '39749146031',
#                                                                              '@idtype': 'SGR'}}}},
#                                 {'@id': '12',
#                                  'ref-fulltext': 'WHO, Essential Diagnostic '
#                                                  'Imaging. http://www. '
#                                                  'who.int/eht/en/DiagnosticImaging.pdf.',
#                                  'ref-info': {'ref-authors': {'collaboration': {'@seq': '1',
#                                                                                 'ce:indexed-name': 'WHO',
#                                                                                 'ce:text': 'WHO'}},
#                                               'ref-sourcetitle': 'Essential '
#                                                                  'Diagnostic '
#                                                                  'Imaging.',
#                                               'ref-website': {'ce:e-address': {'$': 'http://www.who.int/eht/en/DiagnosticImaging.pdf',
#                                                                                '@type': 'email'}},
#                                               'refd-itemidlist': {'itemid': {'$': '77957828197',
#                                                                              '@idtype': 'SGR'}}}},
#                                 {'@id': '13',
#                                  'ref-fulltext': 'World Health Organization. '
#                                                  'Implementing the stop TB '
#                                                  'strategy: a handbook for '
#                                                  'national tuberculosis '
#                                                  'control programmes. Geneva: '
#                                                  'World Health Organization; '
#                                                  '2008.',
#                                  'ref-info': {'ref-authors': {'collaboration': {'@seq': '1',
#                                                                                 'ce:indexed-name': 'World '
#                                                                                                    'Health '
#                                                                                                    'Organization',
#                                                                                 'ce:text': 'World '
#                                                                                            'Health '
#                                                                                            'Organization'}},
#                                               'ref-publicationyear': {'@first': '2008'},
#                                               'ref-sourcetitle': 'Implementing '
#                                                                  'the stop TB '
#                                                                  'strategy: a '
#                                                                  'handbook for '
#                                                                  'national '
#                                                                  'tuberculosis '
#                                                                  'control '
#                                                                  'programmes.',
#                                               'ref-text': 'Geneva: World '
#                                                           'Health Organization',
#                                               'refd-itemidlist': {'itemid': {'$': '70149103504',
#                                                                              '@idtype': 'SGR'}}}},
#                                 {'@id': '14',
#                                  'ref-fulltext': 'Mollura DJ, Morens DM, '
#                                                  'Taubenberger JK, et al. The '
#                                                  'role of radiology in '
#                                                  'influenza: novel H1N1 and '
#                                                  'lessons learned from the '
#                                                  '1918 pandemic. J Am Coll '
#                                                  'Radiol. 2010;7:690-7.',
#                                  'ref-info': {'ref-authors': {'author': [{'@_fa': 'true',
#                                                                           '@seq': '1',
#                                                                           'ce:indexed-name': 'Mollura '
#                                                                                              'D.J.',
#                                                                           'ce:initials': 'D.J.',
#                                                                           'ce:surname': 'Mollura'},
#                                                                          {'@_fa': 'true',
#                                                                           '@seq': '2',
#                                                                           'ce:indexed-name': 'Morens '
#                                                                                              'D.M.',
#                                                                           'ce:initials': 'D.M.',
#                                                                           'ce:surname': 'Morens'},
#                                                                          {'@_fa': 'true',
#                                                                           '@seq': '3',
#                                                                           'ce:indexed-name': 'Taubenberger '
#                                                                                              'J.K.',
#                                                                           'ce:initials': 'J.K.',
#                                                                           'ce:surname': 'Taubenberger'}],
#                                                               'et-al': None},
#                                               'ref-publicationyear': {'@first': '2010'},
#                                               'ref-sourcetitle': 'J Am Coll '
#                                                                  'Radiol.',
#                                               'ref-title': {'ref-titletext': 'The '
#                                                                              'role '
#                                                                              'of '
#                                                                              'radiology '
#                                                                              'in '
#                                                                              'influenza: '
#                                                                              'novel '
#                                                                              'H1N1 '
#                                                                              'and '
#                                                                              'lessons '
#                                                                              'learned '
#                                                                              'from '
#                                                                              'the '
#                                                                              '1918 '
#                                                                              'pandemic'},
#                                               'ref-volisspag': {'pagerange': {'@first': '690',
#                                                                               '@last': '697'},
#                                                                 'voliss': {'@volume': '7'}},
#                                               'refd-itemidlist': {'itemid': {'$': '84928096726',
#                                                                              '@idtype': 'SGR'}}}},
#                                 {'@id': '15',
#                                  'ref-fulltext': 'Paliwal M, Kumar U. Neural '
#                                                  'networks and statistical '
#                                                  'techniques: a review of '
#                                                  'applications. Expert Syst '
#                                                  'Appl. 2009;36:2-17.',
#                                  'ref-info': {'ref-authors': {'author': [{'@_fa': 'true',
#                                                                           '@seq': '1',
#                                                                           'ce:indexed-name': 'Paliwal '
#                                                                                              'M.',
#                                                                           'ce:initials': 'M.',
#                                                                           'ce:surname': 'Paliwal'},
#                                                                          {'@_fa': 'true',
#                                                                           '@seq': '2',
#                                                                           'ce:indexed-name': 'Kumar '
#                                                                                              'U.',
#                                                                           'ce:initials': 'U.',
#                                                                           'ce:surname': 'Kumar'}]},
#                                               'ref-publicationyear': {'@first': '2009'},
#                                               'ref-sourcetitle': 'Expert Syst '
#                                                                  'Appl.',
#                                               'ref-title': {'ref-titletext': 'Neural '
#                                                                              'networks '
#                                                                              'and '
#                                                                              'statistical '
#                                                                              'techniques: '
#                                                                              'a '
#                                                                              'review '
#                                                                              'of '
#                                                                              'applications'},
#                                               'ref-volisspag': {'pagerange': {'@first': '2',
#                                                                               '@last': '17'},
#                                                                 'voliss': {'@volume': '36'}},
#                                               'refd-itemidlist': {'itemid': {'$': '53849126165',
#                                                                              '@idtype': 'SGR'}}}},
#                                 {'@id': '16',
#                                  'ref-fulltext': 'Kansagra AP, Yu JP, '
#                                                  'Chatterjee AR, Lenchik L, '
#                                                  'Chow DS, Prater AB, et al. '
#                                                  'Big data and the future of '
#                                                  'radiology informatics. Acad '
#                                                  'Radiol. 2016;23(1):30-42.',
#                                  'ref-info': {'ref-authors': {'author': [{'@_fa': 'true',
#                                                                           '@seq': '1',
#                                                                           'ce:indexed-name': 'Kansagra '
#                                                                                              'A.P.',
#                                                                           'ce:initials': 'A.P.',
#                                                                           'ce:surname': 'Kansagra'},
#                                                                          {'@_fa': 'true',
#                                                                           '@seq': '2',
#                                                                           'ce:indexed-name': 'Yu '
#                                                                                              'J.P.',
#                                                                           'ce:initials': 'J.P.',
#                                                                           'ce:surname': 'Yu'},
#                                                                          {'@_fa': 'true',
#                                                                           '@seq': '3',
#                                                                           'ce:indexed-name': 'Chatterjee '
#                                                                                              'A.R.',
#                                                                           'ce:initials': 'A.R.',
#                                                                           'ce:surname': 'Chatterjee'},
#                                                                          {'@_fa': 'true',
#                                                                           '@seq': '4',
#                                                                           'ce:indexed-name': 'Lenchik '
#                                                                                              'L.',
#                                                                           'ce:initials': 'L.',
#                                                                           'ce:surname': 'Lenchik'},
#                                                                          {'@_fa': 'true',
#                                                                           '@seq': '5',
#                                                                           'ce:indexed-name': 'Chow '
#                                                                                              'D.S.',
#                                                                           'ce:initials': 'D.S.',
#                                                                           'ce:surname': 'Chow'},
#                                                                          {'@_fa': 'true',
#                                                                           '@seq': '6',
#                                                                           'ce:indexed-name': 'Prater '
#                                                                                              'A.B.',
#                                                                           'ce:initials': 'A.B.',
#                                                                           'ce:surname': 'Prater'}],
#                                                               'et-al': None},
#                                               'ref-publicationyear': {'@first': '2016'},
#                                               'ref-sourcetitle': 'Acad Radiol.',
#                                               'ref-title': {'ref-titletext': 'Big '
#                                                                              'data '
#                                                                              'and '
#                                                                              'the '
#                                                                              'future '
#                                                                              'of '
#                                                                              'radiology '
#                                                                              'informatics'},
#                                               'ref-volisspag': {'pagerange': {'@first': '30',
#                                                                               '@last': '42'},
#                                                                 'voliss': {'@issue': '1',
#                                                                            '@volume': '23'}},
#                                               'refd-itemidlist': {'itemid': {'$': '84949669471',
#                                                                              '@idtype': 'SGR'}}}},
#                                 {'@id': '17',
#                                  'ref-fulltext': 'Recht M, Bryan RN. '
#                                                  'Artificial '
#                                                  'intelligence:threat or boon '
#                                                  'to radiologists? J Am Coll '
#                                                  'Radiol. 2017;14(11):1476-80.',
#                                  'ref-info': {'ref-authors': {'author': [{'@_fa': 'true',
#                                                                           '@seq': '1',
#                                                                           'ce:indexed-name': 'Recht '
#                                                                                              'M.',
#                                                                           'ce:initials': 'M.',
#                                                                           'ce:surname': 'Recht'},
#                                                                          {'@_fa': 'true',
#                                                                           '@seq': '2',
#                                                                           'ce:indexed-name': 'Bryan '
#                                                                                              'R.N.',
#                                                                           'ce:initials': 'R.N.',
#                                                                           'ce:surname': 'Bryan'}]},
#                                               'ref-publicationyear': {'@first': '2017'},
#                                               'ref-sourcetitle': 'J Am Coll '
#                                                                  'Radiol.',
#                                               'ref-title': {'ref-titletext': 'Artificial '
#                                                                              'intelligence:threat '
#                                                                              'or '
#                                                                              'boon '
#                                                                              'to '
#                                                                              'radiologists?'},
#                                               'ref-volisspag': {'pagerange': {'@first': '1476',
#                                                                               '@last': '1480'},
#                                                                 'voliss': {'@issue': '11',
#                                                                            '@volume': '14'}},
#                                               'refd-itemidlist': {'itemid': {'$': '85027675887',
#                                                                              '@idtype': 'SGR'}}}},
#                                 {'@id': '18',
#                                  'ref-fulltext': 'Oakden-Rayner L, Carneiro G, '
#                                                  'Bessen T, Nascimento JC, '
#                                                  'Bradley AP, Palmer LJ. '
#                                                  'Precision radiology: '
#                                                  'predicting longevity using '
#                                                  'feature engineering and deep '
#                                                  'learning methods in a '
#                                                  'radiomics framework. Sci '
#                                                  'Rep. 2017;7(1):1648.',
#                                  'ref-info': {'ref-authors': {'author': [{'@_fa': 'true',
#                                                                           '@seq': '1',
#                                                                           'ce:indexed-name': 'Oakden-Rayner '
#                                                                                              'L.',
#                                                                           'ce:initials': 'L.',
#                                                                           'ce:surname': 'Oakden-Rayner'},
#                                                                          {'@_fa': 'true',
#                                                                           '@seq': '2',
#                                                                           'ce:indexed-name': 'Carneiro '
#                                                                                              'G.',
#                                                                           'ce:initials': 'G.',
#                                                                           'ce:surname': 'Carneiro'},
#                                                                          {'@_fa': 'true',
#                                                                           '@seq': '3',
#                                                                           'ce:indexed-name': 'Bessen '
#                                                                                              'T.',
#                                                                           'ce:initials': 'T.',
#                                                                           'ce:surname': 'Bessen'},
#                                                                          {'@_fa': 'true',
#                                                                           '@seq': '4',
#                                                                           'ce:indexed-name': 'Nascimento '
#                                                                                              'J.C.',
#                                                                           'ce:initials': 'J.C.',
#                                                                           'ce:surname': 'Nascimento'},
#                                                                          {'@_fa': 'true',
#                                                                           '@seq': '5',
#                                                                           'ce:indexed-name': 'Bradley '
#                                                                                              'A.P.',
#                                                                           'ce:initials': 'A.P.',
#                                                                           'ce:surname': 'Bradley'},
#                                                                          {'@_fa': 'true',
#                                                                           '@seq': '6',
#                                                                           'ce:indexed-name': 'Palmer '
#                                                                                              'L.J.',
#                                                                           'ce:initials': 'L.J.',
#                                                                           'ce:surname': 'Palmer'}]},
#                                               'ref-publicationyear': {'@first': '2017'},
#                                               'ref-sourcetitle': 'Sci Rep.',
#                                               'ref-title': {'ref-titletext': 'Precision '
#                                                                              'radiology: '
#                                                                              'predicting '
#                                                                              'longevity '
#                                                                              'using '
#                                                                              'feature '
#                                                                              'engineering '
#                                                                              'and '
#                                                                              'deep '
#                                                                              'learning '
#                                                                              'methods '
#                                                                              'in '
#                                                                              'a '
#                                                                              'radiomics '
#                                                                              'framework'},
#                                               'ref-volisspag': {'pagerange': {'@first': '1648'},
#                                                                 'voliss': {'@issue': '1',
#                                                                            '@volume': '7'}},
#                                               'refd-itemidlist': {'itemid': {'$': '85019233675',
#                                                                              '@idtype': 'SGR'}}}},
#                                 {'@id': '19',
#                                  'ref-fulltext': 'Obermeyer Z, Emanuel EJ. '
#                                                  'Predicting the future - big '
#                                                  'data, machine learning, and '
#                                                  'clinical medicine. N Engl J '
# ...
#                                               'ref-publicationyear': {'@first': '2009'},
#                                               'ref-sourcetitle': 'National '
#                                                                  'Council on '
#                                                                  'Radiation '
#                                                                  'Protection '
#                                                                  'and '
#                                                                  'Measurements.',
#                                               'ref-text': 'Scientific '
#                                                           'Committee 6-2 on '
#                                                           'Radiation Exposure '
#                                                           'of the U.S. '
#                                                           'Population:ionizing '
#                                                           'radiation exposure '
#                                                           'of the population '
#                                                           'of the United '
#                                                           'States: '
#                                                           'recommendations of '
#                                                           'the National '
#                                                           'Council on '
#                                                           'Radiation '
#                                                           'Protection and '
#                                                           'Measurements. '
#                                                           'Bethesda: National '
#                                                           'Council on '
#                                                           'Radiation '
#                                                           'Protection and '
#                                                           'Measurements',
#                                               'refd-itemidlist': {'itemid': {'$': '0005299038',
#                                                                              '@idtype': 'SGR'}}}},
#                                 {'@id': '73',
#                                  'ref-fulltext': 'Marwick TH, Buonocore J. '
#                                                  'Environmental impact of '
#                                                  'cardiac imaging tests for '
#                                                  'the diagnosis of coronary '
#                                                  'artery disease. Heart. '
#                                                  '2011;97:1128-31.',
#                                  'ref-info': {'ref-authors': {'author': [{'@_fa': 'true',
#                                                                           '@seq': '1',
#                                                                           'ce:indexed-name': 'Marwick '
#                                                                                              'T.H.',
#                                                                           'ce:initials': 'T.H.',
#                                                                           'ce:surname': 'Marwick'},
#                                                                          {'@_fa': 'true',
#                                                                           '@seq': '2',
#                                                                           'ce:indexed-name': 'Buonocore '
#                                                                                              'J.',
#                                                                           'ce:initials': 'J.',
#                                                                           'ce:surname': 'Buonocore'}]},
#                                               'ref-publicationyear': {'@first': '2011'},
#                                               'ref-sourcetitle': 'Heart.',
#                                               'ref-title': {'ref-titletext': 'Environmental '
#                                                                              'impact '
#                                                                              'of '
#                                                                              'cardiac '
#                                                                              'imaging '
#                                                                              'tests '
#                                                                              'for '
#                                                                              'the '
#                                                                              'diagnosis '
#                                                                              'of '
#                                                                              'coronary '
#                                                                              'artery '
#                                                                              'disease'},
#                                               'ref-volisspag': {'pagerange': {'@first': '1128',
#                                                                               '@last': '1131'},
#                                                                 'voliss': {'@volume': '97'}},
#                                               'refd-itemidlist': {'itemid': {'$': '79959341720',
#                                                                              '@idtype': 'SGR'}}}},
#                                 {'@id': '74',
#                                  'ref-fulltext': 'International Atomic Energy '
#                                                  'Agency: Thematic plan on '
#                                                  'diagnostic radiology. '
#                                                  'Thematic planning meeting on '
#                                                  'diagnostic radiology; '
#                                                  'Vienna, Austria; 26-30 May '
#                                                  '2003.',
#                                  'ref-info': {'ref-authors': {'collaboration': {'@seq': '1',
#                                                                                 'ce:indexed-name': 'International '
#                                                                                                    'Atomic '
#                                                                                                    'Energy '
#                                                                                                    'Agency: '
#                                                                                                    'Thematic '
#                                                                                                    'plan '
#                                                                                                    'on '
#                                                                                                    'diagnostic '
#                                                                                                    'radiology',
#                                                                                 'ce:text': 'International '
#                                                                                            'Atomic '
#                                                                                            'Energy '
#                                                                                            'Agency: '
#                                                                                            'Thematic '
#                                                                                            'plan '
#                                                                                            'on '
#                                                                                            'diagnostic '
#                                                                                            'radiology'}},
#                                               'ref-publicationyear': {'@first': '2003'},
#                                               'ref-sourcetitle': 'Thematic '
#                                                                  'planning '
#                                                                  'meeting on '
#                                                                  'diagnostic '
#                                                                  'radiology',
#                                               'ref-text': 'Vienna, Austria; '
#                                                           '26-30 May',
#                                               'refd-itemidlist': {'itemid': {'$': '84929053533',
#                                                                              '@idtype': 'SGR'}}}},
#                                 {'@id': '75',
#                                  'ref-fulltext': 'Mahesh M, Morin RL. '
#                                                  'Radiation exposure and '
#                                                  'patient dose in cardiology. '
#                                                  'J Am Coll Radiol. '
#                                                  '2017;14(12):1581-2.',
#                                  'ref-info': {'ref-authors': {'author': [{'@_fa': 'true',
#                                                                           '@seq': '1',
#                                                                           'ce:indexed-name': 'Mahesh '
#                                                                                              'M.',
#                                                                           'ce:initials': 'M.',
#                                                                           'ce:surname': 'Mahesh'},
#                                                                          {'@_fa': 'true',
#                                                                           '@seq': '2',
#                                                                           'ce:indexed-name': 'Morin '
#                                                                                              'R.L.',
#                                                                           'ce:initials': 'R.L.',
#                                                                           'ce:surname': 'Morin'}]},
#                                               'ref-publicationyear': {'@first': '2017'},
#                                               'ref-sourcetitle': 'J Am Coll '
#                                                                  'Radiol.',
#                                               'ref-title': {'ref-titletext': 'Radiation '
#                                                                              'exposure '
#                                                                              'and '
#                                                                              'patient '
#                                                                              'dose '
#                                                                              'in '
#                                                                              'cardiology'},
#                                               'ref-volisspag': {'pagerange': {'@first': '1581',
#                                                                               '@last': '1582'},
#                                                                 'voliss': {'@issue': '12',
#                                                                            '@volume': '14'}},
#                                               'refd-itemidlist': {'itemid': {'$': '85031752714',
#                                                                              '@idtype': 'SGR'}}}},
#                                 {'@id': '76',
#                                  'ref-fulltext': 'Tucker EW, Jain SK, Mahesh '
#                                                  'M. Balancing the risks of '
#                                                  'radiation and anesthesia in '
#                                                  'pediatric patients. J Am '
#                                                  'Coll Radiol. '
#                                                  '2017;14(11):1459-61.',
#                                  'ref-info': {'ref-authors': {'author': [{'@_fa': 'true',
#                                                                           '@seq': '1',
#                                                                           'ce:indexed-name': 'Tucker '
#                                                                                              'E.W.',
#                                                                           'ce:initials': 'E.W.',
#                                                                           'ce:surname': 'Tucker'},
#                                                                          {'@_fa': 'true',
#                                                                           '@seq': '2',
#                                                                           'ce:indexed-name': 'Jain '
#                                                                                              'S.K.',
#                                                                           'ce:initials': 'S.K.',
#                                                                           'ce:surname': 'Jain'},
#                                                                          {'@_fa': 'true',
#                                                                           '@seq': '3',
#                                                                           'ce:indexed-name': 'Mahesh '
#                                                                                              'M.',
#                                                                           'ce:initials': 'M.',
#                                                                           'ce:surname': 'Mahesh'}]},
#                                               'ref-publicationyear': {'@first': '2017'},
#                                               'ref-sourcetitle': 'J Am Coll '
#                                                                  'Radiol.',
#                                               'ref-title': {'ref-titletext': 'Balancing '
#                                                                              'the '
#                                                                              'risks '
#                                                                              'of '
#                                                                              'radiation '
#                                                                              'and '
#                                                                              'anesthesia '
#                                                                              'in '
#                                                                              'pediatric '
#                                                                              'patients'},
#                                               'ref-volisspag': {'pagerange': {'@first': '1459',
#                                                                               '@last': '1461'},
#                                                                 'voliss': {'@issue': '11',
#                                                                            '@volume': '14'}},
#                                               'refd-itemidlist': {'itemid': {'$': '85025671230',
#                                                                              '@idtype': 'SGR'}}}}]}}

# %%
def print_json_keys(data, parent_key=''):
    """
    Recursively prints all keys in a nested JSON object.
    If the value of a key is a dictionary, it goes deeper into the dictionary.
    """
    if isinstance(data, dict):  # If the data is a dictionary
        for key, value in data.items():
            new_key = f"{parent_key}.{key}" if parent_key else key
            print(new_key)  # Print the key
            print_json_keys(value, new_key)  # Recursively go deeper
    elif isinstance(data, list):  # If the data is a list
        for i, item in enumerate(data):
            new_key = f"{parent_key}[{i}]"
            print_json_keys(item, new_key)  # Recursively go deeper into each list item

# %%
print_json_keys(data)  # Call the function with the data
# Out:
# abstracts-retrieval-response
# abstracts-retrieval-response.item
# abstracts-retrieval-response.item.ait:process-info
# abstracts-retrieval-response.item.ait:process-info.ait:status
# abstracts-retrieval-response.item.ait:process-info.ait:status.@state
# abstracts-retrieval-response.item.ait:process-info.ait:status.@type
# abstracts-retrieval-response.item.ait:process-info.ait:status.@stage
# abstracts-retrieval-response.item.ait:process-info.ait:date-delivered
# abstracts-retrieval-response.item.ait:process-info.ait:date-delivered.@day
# abstracts-retrieval-response.item.ait:process-info.ait:date-delivered.@timestamp
# abstracts-retrieval-response.item.ait:process-info.ait:date-delivered.@year
# abstracts-retrieval-response.item.ait:process-info.ait:date-delivered.@month
# abstracts-retrieval-response.item.ait:process-info.ait:date-sort
# abstracts-retrieval-response.item.ait:process-info.ait:date-sort.@day
# abstracts-retrieval-response.item.ait:process-info.ait:date-sort.@year
# abstracts-retrieval-response.item.ait:process-info.ait:date-sort.@month
# abstracts-retrieval-response.item.bibrecord
# abstracts-retrieval-response.item.bibrecord.head
# abstracts-retrieval-response.item.bibrecord.head.author-group
# abstracts-retrieval-response.item.bibrecord.head.author-group[0].affiliation
# abstracts-retrieval-response.item.bibrecord.head.author-group[0].affiliation.country
# abstracts-retrieval-response.item.bibrecord.head.author-group[0].affiliation.@afid
# abstracts-retrieval-response.item.bibrecord.head.author-group[0].affiliation.@country
# abstracts-retrieval-response.item.bibrecord.head.author-group[0].affiliation.city
# abstracts-retrieval-response.item.bibrecord.head.author-group[0].affiliation.organization
# abstracts-retrieval-response.item.bibrecord.head.author-group[0].affiliation.organization[0].$
# abstracts-retrieval-response.item.bibrecord.head.author-group[0].affiliation.organization[1].$
# abstracts-retrieval-response.item.bibrecord.head.author-group[0].affiliation.organization[2].$
# abstracts-retrieval-response.item.bibrecord.head.author-group[0].affiliation.affiliation-id
# abstracts-retrieval-response.item.bibrecord.head.author-group[0].affiliation.affiliation-id.@afid
# abstracts-retrieval-response.item.bibrecord.head.author-group[0].affiliation.affiliation-id.@dptid
# abstracts-retrieval-response.item.bibrecord.head.author-group[0].affiliation.@dptid
# abstracts-retrieval-response.item.bibrecord.head.author-group[0].author
# abstracts-retrieval-response.item.bibrecord.head.author-group[0].author[0].ce:given-name
# abstracts-retrieval-response.item.bibrecord.head.author-group[0].author[0].preferred-name
# abstracts-retrieval-response.item.bibrecord.head.author-group[0].author[0].preferred-name.ce:given-name
# abstracts-retrieval-response.item.bibrecord.head.author-group[0].author[0].preferred-name.ce:initials
# abstracts-retrieval-response.item.bibrecord.head.author-group[0].author[0].preferred-name.ce:surname
# abstracts-retrieval-response.item.bibrecord.head.author-group[0].author[0].preferred-name.ce:indexed-name
# abstracts-retrieval-response.item.bibrecord.head.author-group[0].author[0].@seq
# abstracts-retrieval-response.item.bibrecord.head.author-group[0].author[0].ce:initials
# abstracts-retrieval-response.item.bibrecord.head.author-group[0].author[0].@_fa
# abstracts-retrieval-response.item.bibrecord.head.author-group[0].author[0].@type
# abstracts-retrieval-response.item.bibrecord.head.author-group[0].author[0].ce:degrees
# abstracts-retrieval-response.item.bibrecord.head.author-group[0].author[0].ce:surname
# abstracts-retrieval-response.item.bibrecord.head.author-group[0].author[0].@auid
# abstracts-retrieval-response.item.bibrecord.head.author-group[0].author[0].ce:indexed-name
# abstracts-retrieval-response.item.bibrecord.head.author-group[1].affiliation
# abstracts-retrieval-response.item.bibrecord.head.author-group[1].affiliation.country
# abstracts-retrieval-response.item.bibrecord.head.author-group[1].affiliation.@afid
# abstracts-retrieval-response.item.bibrecord.head.author-group[1].affiliation.@country
# abstracts-retrieval-response.item.bibrecord.head.author-group[1].affiliation.city
# abstracts-retrieval-response.item.bibrecord.head.author-group[1].affiliation.organization
# abstracts-retrieval-response.item.bibrecord.head.author-group[1].affiliation.organization[0].$
# abstracts-retrieval-response.item.bibrecord.head.author-group[1].affiliation.organization[1].$
# abstracts-retrieval-response.item.bibrecord.head.author-group[1].affiliation.affiliation-id
# abstracts-retrieval-response.item.bibrecord.head.author-group[1].affiliation.affiliation-id.@afid
# abstracts-retrieval-response.item.bibrecord.head.author-group[1].affiliation.affiliation-id.@dptid
# abstracts-retrieval-response.item.bibrecord.head.author-group[1].affiliation.state
# abstracts-retrieval-response.item.bibrecord.head.author-group[1].affiliation.@dptid
# abstracts-retrieval-response.item.bibrecord.head.author-group[1].author
# abstracts-retrieval-response.item.bibrecord.head.author-group[1].author[0].ce:given-name
# abstracts-retrieval-response.item.bibrecord.head.author-group[1].author[0].preferred-name
# abstracts-retrieval-response.item.bibrecord.head.author-group[1].author[0].preferred-name.ce:given-name
# abstracts-retrieval-response.item.bibrecord.head.author-group[1].author[0].preferred-name.ce:initials
# abstracts-retrieval-response.item.bibrecord.head.author-group[1].author[0].preferred-name.ce:surname
# abstracts-retrieval-response.item.bibrecord.head.author-group[1].author[0].preferred-name.ce:indexed-name
# abstracts-retrieval-response.item.bibrecord.head.author-group[1].author[0].@seq
# abstracts-retrieval-response.item.bibrecord.head.author-group[1].author[0].ce:initials
# abstracts-retrieval-response.item.bibrecord.head.author-group[1].author[0].@_fa
# abstracts-retrieval-response.item.bibrecord.head.author-group[1].author[0].@type
# abstracts-retrieval-response.item.bibrecord.head.author-group[1].author[0].ce:degrees
# abstracts-retrieval-response.item.bibrecord.head.author-group[1].author[0].ce:surname
# abstracts-retrieval-response.item.bibrecord.head.author-group[1].author[0].@auid
# abstracts-retrieval-response.item.bibrecord.head.author-group[1].author[0].ce:indexed-name
# abstracts-retrieval-response.item.bibrecord.head.author-group[2].affiliation
# abstracts-retrieval-response.item.bibrecord.head.author-group[2].affiliation.country
# abstracts-retrieval-response.item.bibrecord.head.author-group[2].affiliation.@afid
# abstracts-retrieval-response.item.bibrecord.head.author-group[2].affiliation.@country
# abstracts-retrieval-response.item.bibrecord.head.author-group[2].affiliation.city
# abstracts-retrieval-response.item.bibrecord.head.author-group[2].affiliation.organization
# abstracts-retrieval-response.item.bibrecord.head.author-group[2].affiliation.organization.$
# abstracts-retrieval-response.item.bibrecord.head.author-group[2].affiliation.affiliation-id
# abstracts-retrieval-response.item.bibrecord.head.author-group[2].affiliation.affiliation-id.@afid
# abstracts-retrieval-response.item.bibrecord.head.author-group[2].author
# abstracts-retrieval-response.item.bibrecord.head.author-group[2].author[0].ce:given-name
# abstracts-retrieval-response.item.bibrecord.head.author-group[2].author[0].preferred-name
# abstracts-retrieval-response.item.bibrecord.head.author-group[2].author[0].preferred-name.ce:given-name
# abstracts-retrieval-response.item.bibrecord.head.author-group[2].author[0].preferred-name.ce:initials
# abstracts-retrieval-response.item.bibrecord.head.author-group[2].author[0].preferred-name.ce:surname
# abstracts-retrieval-response.item.bibrecord.head.author-group[2].author[0].preferred-name.ce:indexed-name
# abstracts-retrieval-response.item.bibrecord.head.author-group[2].author[0].@seq
# abstracts-retrieval-response.item.bibrecord.head.author-group[2].author[0].ce:initials
# abstracts-retrieval-response.item.bibrecord.head.author-group[2].author[0].@_fa
# abstracts-retrieval-response.item.bibrecord.head.author-group[2].author[0].@type
# abstracts-retrieval-response.item.bibrecord.head.author-group[2].author[0].ce:degrees
# abstracts-retrieval-response.item.bibrecord.head.author-group[2].author[0].ce:surname
# abstracts-retrieval-response.item.bibrecord.head.author-group[2].author[0].@auid
# abstracts-retrieval-response.item.bibrecord.head.author-group[2].author[0].ce:indexed-name
# abstracts-retrieval-response.item.bibrecord.head.author-group[3].affiliation
# abstracts-retrieval-response.item.bibrecord.head.author-group[3].affiliation.country
# abstracts-retrieval-response.item.bibrecord.head.author-group[3].affiliation.@afid
# abstracts-retrieval-response.item.bibrecord.head.author-group[3].affiliation.@country
# abstracts-retrieval-response.item.bibrecord.head.author-group[3].affiliation.city
# abstracts-retrieval-response.item.bibrecord.head.author-group[3].affiliation.organization
# abstracts-retrieval-response.item.bibrecord.head.author-group[3].affiliation.organization[0].$
# abstracts-retrieval-response.item.bibrecord.head.author-group[3].affiliation.organization[1].$
# abstracts-retrieval-response.item.bibrecord.head.author-group[3].affiliation.affiliation-id
# abstracts-retrieval-response.item.bibrecord.head.author-group[3].affiliation.affiliation-id.@afid
# abstracts-retrieval-response.item.bibrecord.head.author-group[3].affiliation.state
# abstracts-retrieval-response.item.bibrecord.head.author-group[3].author
# abstracts-retrieval-response.item.bibrecord.head.author-group[3].author[0].ce:given-name
# abstracts-retrieval-response.item.bibrecord.head.author-group[3].author[0].preferred-name
# abstracts-retrieval-response.item.bibrecord.head.author-group[3].author[0].preferred-name.ce:given-name
# abstracts-retrieval-response.item.bibrecord.head.author-group[3].author[0].preferred-name.ce:initials
# abstracts-retrieval-response.item.bibrecord.head.author-group[3].author[0].preferred-name.ce:surname
# abstracts-retrieval-response.item.bibrecord.head.author-group[3].author[0].preferred-name.ce:indexed-name
# abstracts-retrieval-response.item.bibrecord.head.author-group[3].author[0].@seq
# abstracts-retrieval-response.item.bibrecord.head.author-group[3].author[0].ce:initials
# abstracts-retrieval-response.item.bibrecord.head.author-group[3].author[0].@_fa
# abstracts-retrieval-response.item.bibrecord.head.author-group[3].author[0].@type
# abstracts-retrieval-response.item.bibrecord.head.author-group[3].author[0].ce:degrees
# abstracts-retrieval-response.item.bibrecord.head.author-group[3].author[0].ce:surname
# abstracts-retrieval-response.item.bibrecord.head.author-group[3].author[0].@auid
# abstracts-retrieval-response.item.bibrecord.head.author-group[3].author[0].ce:indexed-name
# abstracts-retrieval-response.item.bibrecord.head.author-group[4].affiliation
# abstracts-retrieval-response.item.bibrecord.head.author-group[4].affiliation.country
# abstracts-retrieval-response.item.bibrecord.head.author-group[4].affiliation.@afid
# abstracts-retrieval-response.item.bibrecord.head.author-group[4].affiliation.@country
# abstracts-retrieval-response.item.bibrecord.head.author-group[4].affiliation.city
# abstracts-retrieval-response.item.bibrecord.head.author-group[4].affiliation.organization
# abstracts-retrieval-response.item.bibrecord.head.author-group[4].affiliation.organization[0].$
# abstracts-retrieval-response.item.bibrecord.head.author-group[4].affiliation.organization[1].$
# abstracts-retrieval-response.item.bibrecord.head.author-group[4].affiliation.affiliation-id
# abstracts-retrieval-response.item.bibrecord.head.author-group[4].affiliation.affiliation-id[0].@afid
# abstracts-retrieval-response.item.bibrecord.head.author-group[4].affiliation.affiliation-id[1].@afid
# abstracts-retrieval-response.item.bibrecord.head.author-group[4].affiliation.state
# abstracts-retrieval-response.item.bibrecord.head.author-group[4].author
# abstracts-retrieval-response.item.bibrecord.head.author-group[4].author[0].ce:given-name
# abstracts-retrieval-response.item.bibrecord.head.author-group[4].author[0].preferred-name
# abstracts-retrieval-response.item.bibrecord.head.author-group[4].author[0].preferred-name.ce:given-name
# abstracts-retrieval-response.item.bibrecord.head.author-group[4].author[0].preferred-name.ce:initials
# abstracts-retrieval-response.item.bibrecord.head.author-group[4].author[0].preferred-name.ce:surname
# abstracts-retrieval-response.item.bibrecord.head.author-group[4].author[0].preferred-name.ce:indexed-name
# abstracts-retrieval-response.item.bibrecord.head.author-group[4].author[0].@seq
# abstracts-retrieval-response.item.bibrecord.head.author-group[4].author[0].ce:initials
# abstracts-retrieval-response.item.bibrecord.head.author-group[4].author[0].@_fa
# abstracts-retrieval-response.item.bibrecord.head.author-group[4].author[0].@type
# abstracts-retrieval-response.item.bibrecord.head.author-group[4].author[0].ce:degrees
# abstracts-retrieval-response.item.bibrecord.head.author-group[4].author[0].ce:surname
# abstracts-retrieval-response.item.bibrecord.head.author-group[4].author[0].@auid
# abstracts-retrieval-response.item.bibrecord.head.author-group[4].author[0].ce:indexed-name
# abstracts-retrieval-response.item.bibrecord.head.author-group[5].affiliation
# abstracts-retrieval-response.item.bibrecord.head.author-group[5].affiliation.country
# abstracts-retrieval-response.item.bibrecord.head.author-group[5].affiliation.@afid
# abstracts-retrieval-response.item.bibrecord.head.author-group[5].affiliation.@country
# abstracts-retrieval-response.item.bibrecord.head.author-group[5].affiliation.city
# abstracts-retrieval-response.item.bibrecord.head.author-group[5].affiliation.organization
# abstracts-retrieval-response.item.bibrecord.head.author-group[5].affiliation.organization[0].$
# abstracts-retrieval-response.item.bibrecord.head.author-group[5].affiliation.organization[1].$
# abstracts-retrieval-response.item.bibrecord.head.author-group[5].affiliation.affiliation-id
# abstracts-retrieval-response.item.bibrecord.head.author-group[5].affiliation.affiliation-id.@afid
# abstracts-retrieval-response.item.bibrecord.head.author-group[5].affiliation.state
# abstracts-retrieval-response.item.bibrecord.head.author-group[5].author
# abstracts-retrieval-response.item.bibrecord.head.author-group[5].author[0].ce:given-name
# abstracts-retrieval-response.item.bibrecord.head.author-group[5].author[0].preferred-name
# abstracts-retrieval-response.item.bibrecord.head.author-group[5].author[0].preferred-name.ce:given-name
# abstracts-retrieval-response.item.bibrecord.head.author-group[5].author[0].preferred-name.ce:initials
# abstracts-retrieval-response.item.bibrecord.head.author-group[5].author[0].preferred-name.ce:surname
# abstracts-retrieval-response.item.bibrecord.head.author-group[5].author[0].preferred-name.ce:indexed-name
# abstracts-retrieval-response.item.bibrecord.head.author-group[5].author[0].@seq
# abstracts-retrieval-response.item.bibrecord.head.author-group[5].author[0].ce:initials
# abstracts-retrieval-response.item.bibrecord.head.author-group[5].author[0].@_fa
# abstracts-retrieval-response.item.bibrecord.head.author-group[5].author[0].@type
# abstracts-retrieval-response.item.bibrecord.head.author-group[5].author[0].ce:degrees
# abstracts-retrieval-response.item.bibrecord.head.author-group[5].author[0].ce:surname
# abstracts-retrieval-response.item.bibrecord.head.author-group[5].author[0].@auid
# abstracts-retrieval-response.item.bibrecord.head.author-group[5].author[0].ce:indexed-name
# abstracts-retrieval-response.item.bibrecord.head.citation-title
# abstracts-retrieval-response.item.bibrecord.head.abstracts
# abstracts-retrieval-response.item.bibrecord.head.correspondence
# abstracts-retrieval-response.item.bibrecord.head.correspondence.affiliation
# abstracts-retrieval-response.item.bibrecord.head.correspondence.affiliation.country
# abstracts-retrieval-response.item.bibrecord.head.correspondence.affiliation.@country
# abstracts-retrieval-response.item.bibrecord.head.correspondence.affiliation.city
# abstracts-retrieval-response.item.bibrecord.head.correspondence.affiliation.organization
# abstracts-retrieval-response.item.bibrecord.head.correspondence.affiliation.organization[0].$
# abstracts-retrieval-response.item.bibrecord.head.correspondence.affiliation.organization[1].$
# abstracts-retrieval-response.item.bibrecord.head.correspondence.affiliation.organization[2].$
# abstracts-retrieval-response.item.bibrecord.head.correspondence.person
# abstracts-retrieval-response.item.bibrecord.head.correspondence.person.ce:given-name
# abstracts-retrieval-response.item.bibrecord.head.correspondence.person.ce:initials
# abstracts-retrieval-response.item.bibrecord.head.correspondence.person.ce:degrees
# abstracts-retrieval-response.item.bibrecord.head.correspondence.person.ce:surname
# abstracts-retrieval-response.item.bibrecord.head.correspondence.person.ce:indexed-name
# abstracts-retrieval-response.item.bibrecord.head.citation-info
# abstracts-retrieval-response.item.bibrecord.head.citation-info.citation-type
# abstracts-retrieval-response.item.bibrecord.head.citation-info.citation-type.@code
# abstracts-retrieval-response.item.bibrecord.head.citation-info.citation-language
# abstracts-retrieval-response.item.bibrecord.head.citation-info.citation-language.@language
# abstracts-retrieval-response.item.bibrecord.head.citation-info.citation-language.@xml:lang
# abstracts-retrieval-response.item.bibrecord.head.source
# abstracts-retrieval-response.item.bibrecord.head.source.sourcetitle-abbrev
# abstracts-retrieval-response.item.bibrecord.head.source.website
# abstracts-retrieval-response.item.bibrecord.head.source.website.ce:e-address
# abstracts-retrieval-response.item.bibrecord.head.source.website.ce:e-address.$
# abstracts-retrieval-response.item.bibrecord.head.source.website.ce:e-address.@type
# abstracts-retrieval-response.item.bibrecord.head.source.@country
# abstracts-retrieval-response.item.bibrecord.head.source.translated-sourcetitle
# abstracts-retrieval-response.item.bibrecord.head.source.translated-sourcetitle.@xml:lang
# abstracts-retrieval-response.item.bibrecord.head.source.volisspag
# abstracts-retrieval-response.item.bibrecord.head.source.volisspag.pagerange
# abstracts-retrieval-response.item.bibrecord.head.source.volisspag.pagerange.@first
# abstracts-retrieval-response.item.bibrecord.head.source.volisspag.pagerange.@last
# abstracts-retrieval-response.item.bibrecord.head.source.@type
# abstracts-retrieval-response.item.bibrecord.head.source.publicationyear
# abstracts-retrieval-response.item.bibrecord.head.source.publicationyear.@first
# abstracts-retrieval-response.item.bibrecord.head.source.isbn
# abstracts-retrieval-response.item.bibrecord.head.source.isbn[0].@level
# abstracts-retrieval-response.item.bibrecord.head.source.isbn[0].$
# abstracts-retrieval-response.item.bibrecord.head.source.isbn[0].@type
# abstracts-retrieval-response.item.bibrecord.head.source.isbn[0].@length
# abstracts-retrieval-response.item.bibrecord.head.source.isbn[1].@level
# abstracts-retrieval-response.item.bibrecord.head.source.isbn[1].$
# abstracts-retrieval-response.item.bibrecord.head.source.isbn[1].@type
# abstracts-retrieval-response.item.bibrecord.head.source.isbn[1].@length
# abstracts-retrieval-response.item.bibrecord.head.source.publisher
# abstracts-retrieval-response.item.bibrecord.head.source.publisher.publishername
# abstracts-retrieval-response.item.bibrecord.head.source.sourcetitle
# abstracts-retrieval-response.item.bibrecord.head.source.@srcid
# abstracts-retrieval-response.item.bibrecord.head.source.publicationdate
# abstracts-retrieval-response.item.bibrecord.head.source.publicationdate.month
# abstracts-retrieval-response.item.bibrecord.head.source.publicationdate.year
# abstracts-retrieval-response.item.bibrecord.head.source.publicationdate.date-text
# abstracts-retrieval-response.item.bibrecord.head.source.publicationdate.date-text.@xfab-added
# abstracts-retrieval-response.item.bibrecord.head.source.publicationdate.date-text.$
# abstracts-retrieval-response.item.bibrecord.head.source.publicationdate.day
# abstracts-retrieval-response.item.bibrecord.head.enhancement
# abstracts-retrieval-response.item.bibrecord.head.enhancement.classificationgroup
# abstracts-retrieval-response.item.bibrecord.head.enhancement.classificationgroup.classifications
# abstracts-retrieval-response.item.bibrecord.head.enhancement.classificationgroup.classifications[0].@type
# abstracts-retrieval-response.item.bibrecord.head.enhancement.classificationgroup.classifications[0].classification
# abstracts-retrieval-response.item.bibrecord.head.enhancement.classificationgroup.classifications[1].@type
# abstracts-retrieval-response.item.bibrecord.head.enhancement.classificationgroup.classifications[1].classification
# abstracts-retrieval-response.item.bibrecord.item-info
# abstracts-retrieval-response.item.bibrecord.item-info.copyright
# abstracts-retrieval-response.item.bibrecord.item-info.copyright.$
# abstracts-retrieval-response.item.bibrecord.item-info.copyright.@type
# abstracts-retrieval-response.item.bibrecord.item-info.dbcollection
# abstracts-retrieval-response.item.bibrecord.item-info.dbcollection[0].$
# abstracts-retrieval-response.item.bibrecord.item-info.dbcollection[1].$
# abstracts-retrieval-response.item.bibrecord.item-info.dbcollection[2].$
# abstracts-retrieval-response.item.bibrecord.item-info.history
# abstracts-retrieval-response.item.bibrecord.item-info.history.date-created
# abstracts-retrieval-response.item.bibrecord.item-info.history.date-created.@day
# abstracts-retrieval-response.item.bibrecord.item-info.history.date-created.@timestamp
# abstracts-retrieval-response.item.bibrecord.item-info.history.date-created.@year
# abstracts-retrieval-response.item.bibrecord.item-info.history.date-created.@month
# abstracts-retrieval-response.item.bibrecord.item-info.itemidlist
# abstracts-retrieval-response.item.bibrecord.item-info.itemidlist.itemid
# abstracts-retrieval-response.item.bibrecord.item-info.itemidlist.itemid[0].$
# abstracts-retrieval-response.item.bibrecord.item-info.itemidlist.itemid[0].@idtype
# abstracts-retrieval-response.item.bibrecord.item-info.itemidlist.itemid[1].$
# abstracts-retrieval-response.item.bibrecord.item-info.itemidlist.itemid[1].@idtype
# abstracts-retrieval-response.item.bibrecord.item-info.itemidlist.itemid[2].$
# abstracts-retrieval-response.item.bibrecord.item-info.itemidlist.itemid[2].@idtype
# abstracts-retrieval-response.item.bibrecord.item-info.itemidlist.itemid[3].$
# abstracts-retrieval-response.item.bibrecord.item-info.itemidlist.itemid[3].@idtype
# abstracts-retrieval-response.item.bibrecord.item-info.itemidlist.itemid[4].$
# abstracts-retrieval-response.item.bibrecord.item-info.itemidlist.itemid[4].@idtype
# abstracts-retrieval-response.item.bibrecord.item-info.itemidlist.itemid[5].$
# abstracts-retrieval-response.item.bibrecord.item-info.itemidlist.itemid[5].@idtype
# abstracts-retrieval-response.item.bibrecord.item-info.itemidlist.itemid[6].$
# abstracts-retrieval-response.item.bibrecord.item-info.itemidlist.itemid[6].@idtype
# abstracts-retrieval-response.item.bibrecord.item-info.itemidlist.itemid[7].$
# abstracts-retrieval-response.item.bibrecord.item-info.itemidlist.itemid[7].@idtype
# abstracts-retrieval-response.item.bibrecord.item-info.itemidlist.ce:doi
# abstracts-retrieval-response.item.bibrecord.tail
# abstracts-retrieval-response.item.bibrecord.tail.bibliography
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.@refcount
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[0].ref-fulltext
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[0].@id
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[0].ref-info
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[0].ref-info.ref-publicationyear
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[0].ref-info.ref-publicationyear.@first
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[0].ref-info.ref-title
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[0].ref-info.ref-title.ref-titletext
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[0].ref-info.refd-itemidlist
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[0].ref-info.refd-itemidlist.itemid
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[0].ref-info.refd-itemidlist.itemid.$
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[0].ref-info.refd-itemidlist.itemid.@idtype
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[0].ref-info.ref-volisspag
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[0].ref-info.ref-volisspag.voliss
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[0].ref-info.ref-volisspag.voliss.@volume
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[0].ref-info.ref-volisspag.pagerange
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[0].ref-info.ref-volisspag.pagerange.@first
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[0].ref-info.ref-volisspag.pagerange.@last
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[0].ref-info.ref-authors
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[0].ref-info.ref-authors.author
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[0].ref-info.ref-authors.author[0].@seq
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[0].ref-info.ref-authors.author[0].ce:initials
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[0].ref-info.ref-authors.author[0].@_fa
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[0].ref-info.ref-authors.author[0].ce:surname
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[0].ref-info.ref-authors.author[0].ce:indexed-name
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[0].ref-info.ref-sourcetitle
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[1].ref-fulltext
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[1].@id
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[1].ref-info
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[1].ref-info.ref-publicationyear
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[1].ref-info.ref-publicationyear.@first
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[1].ref-info.ref-title
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[1].ref-info.ref-title.ref-titletext
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[1].ref-info.refd-itemidlist
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[1].ref-info.refd-itemidlist.itemid
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[1].ref-info.refd-itemidlist.itemid.$
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[1].ref-info.refd-itemidlist.itemid.@idtype
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[1].ref-info.ref-volisspag
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[1].ref-info.ref-volisspag.voliss
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[1].ref-info.ref-volisspag.voliss.@volume
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[1].ref-info.ref-volisspag.pagerange
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[1].ref-info.ref-volisspag.pagerange.@first
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[1].ref-info.ref-text
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[1].ref-info.ref-authors
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[1].ref-info.ref-authors.collaboration
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[1].ref-info.ref-authors.collaboration.@seq
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[1].ref-info.ref-authors.collaboration.ce:text
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[1].ref-info.ref-authors.collaboration.ce:indexed-name
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[1].ref-info.ref-sourcetitle
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[2].ref-fulltext
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[2].@id
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[2].ref-info
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[2].ref-info.ref-publicationyear
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[2].ref-info.ref-publicationyear.@first
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[2].ref-info.refd-itemidlist
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[2].ref-info.refd-itemidlist.itemid
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[2].ref-info.refd-itemidlist.itemid.$
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[2].ref-info.refd-itemidlist.itemid.@idtype
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[2].ref-info.ref-text
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[2].ref-info.ref-authors
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[2].ref-info.ref-authors.author
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[2].ref-info.ref-authors.author[0].@seq
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[2].ref-info.ref-authors.author[0].ce:initials
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[2].ref-info.ref-authors.author[0].@_fa
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[2].ref-info.ref-authors.author[0].ce:surname
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[2].ref-info.ref-authors.author[0].ce:indexed-name
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[2].ref-info.ref-authors.author[1].@seq
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[2].ref-info.ref-authors.author[1].ce:initials
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[2].ref-info.ref-authors.author[1].@_fa
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[2].ref-info.ref-authors.author[1].ce:surname
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[2].ref-info.ref-authors.author[1].ce:indexed-name
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[2].ref-info.ref-sourcetitle
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[3].ref-fulltext
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[3].@id
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[3].ref-info
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[3].ref-info.ref-publicationyear
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[3].ref-info.ref-publicationyear.@first
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[3].ref-info.refd-itemidlist
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[3].ref-info.refd-itemidlist.itemid
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[3].ref-info.refd-itemidlist.itemid.$
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[3].ref-info.refd-itemidlist.itemid.@idtype
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[3].ref-info.ref-text
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[3].ref-info.ref-authors
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[3].ref-info.ref-authors.author
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[3].ref-info.ref-authors.author[0].@seq
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[3].ref-info.ref-authors.author[0].ce:initials
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[3].ref-info.ref-authors.author[0].@_fa
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[3].ref-info.ref-authors.author[0].ce:surname
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[3].ref-info.ref-authors.author[0].ce:indexed-name
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[3].ref-info.ref-sourcetitle
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[4].ref-fulltext
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[4].@id
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[4].ref-info
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[4].ref-info.ref-publicationyear
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[4].ref-info.ref-publicationyear.@first
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[4].ref-info.ref-website
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[4].ref-info.ref-website.ce:e-address
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[4].ref-info.ref-website.ce:e-address.$
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[4].ref-info.ref-website.ce:e-address.@type
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[4].ref-info.refd-itemidlist
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[4].ref-info.refd-itemidlist.itemid
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[4].ref-info.refd-itemidlist.itemid.$
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[4].ref-info.refd-itemidlist.itemid.@idtype
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[4].ref-info.ref-text
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[4].ref-info.ref-sourcetitle
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[5].ref-fulltext
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[5].@id
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[5].ref-info
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[5].ref-info.ref-website
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[5].ref-info.ref-website.ce:e-address
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[5].ref-info.ref-website.ce:e-address.$
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[5].ref-info.ref-website.ce:e-address.@type
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[5].ref-info.refd-itemidlist
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[5].ref-info.refd-itemidlist.itemid
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[5].ref-info.refd-itemidlist.itemid.$
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[5].ref-info.refd-itemidlist.itemid.@idtype
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[5].ref-info.ref-text
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[5].ref-info.ref-sourcetitle
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[6].ref-fulltext
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[6].@id
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[6].ref-info
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[6].ref-info.ref-publicationyear
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[6].ref-info.ref-publicationyear.@first
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[6].ref-info.ref-website
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[6].ref-info.ref-website.ce:e-address
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[6].ref-info.ref-website.ce:e-address.$
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[6].ref-info.ref-website.ce:e-address.@type
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[6].ref-info.refd-itemidlist
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[6].ref-info.refd-itemidlist.itemid
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[6].ref-info.refd-itemidlist.itemid.$
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[6].ref-info.refd-itemidlist.itemid.@idtype
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[6].ref-info.ref-text
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[6].ref-info.ref-sourcetitle
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[7].ref-fulltext
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[7].@id
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[7].ref-info
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[7].ref-info.ref-publicationyear
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[7].ref-info.ref-publicationyear.@first
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[7].ref-info.refd-itemidlist
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[7].ref-info.refd-itemidlist.itemid
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[7].ref-info.refd-itemidlist.itemid.$
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[7].ref-info.refd-itemidlist.itemid.@idtype
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[7].ref-info.ref-text
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[7].ref-info.ref-authors
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[7].ref-info.ref-authors.author
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[7].ref-info.ref-authors.author[0].@seq
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[7].ref-info.ref-authors.author[0].ce:initials
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[7].ref-info.ref-authors.author[0].@_fa
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[7].ref-info.ref-authors.author[0].ce:surname
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[7].ref-info.ref-authors.author[0].ce:indexed-name
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[7].ref-info.ref-sourcetitle
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[8].ref-fulltext
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[8].@id
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[8].ref-info
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[8].ref-info.ref-publicationyear
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[8].ref-info.ref-publicationyear.@first
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[8].ref-info.ref-website
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[8].ref-info.ref-website.ce:e-address
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[8].ref-info.ref-website.ce:e-address.$
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[8].ref-info.ref-website.ce:e-address.@type
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[8].ref-info.refd-itemidlist
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[8].ref-info.refd-itemidlist.itemid
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[8].ref-info.refd-itemidlist.itemid.$
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[8].ref-info.refd-itemidlist.itemid.@idtype
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[8].ref-info.ref-text
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[8].ref-info.ref-sourcetitle
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[9].ref-fulltext
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[9].@id
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[9].ref-info
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[9].ref-info.ref-publicationyear
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[9].ref-info.ref-publicationyear.@first
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[9].ref-info.ref-title
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[9].ref-info.ref-title.ref-titletext
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[9].ref-info.refd-itemidlist
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[9].ref-info.refd-itemidlist.itemid
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[9].ref-info.refd-itemidlist.itemid.$
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[9].ref-info.refd-itemidlist.itemid.@idtype
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[9].ref-info.ref-volisspag
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[9].ref-info.ref-volisspag.voliss
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[9].ref-info.ref-volisspag.voliss.@volume
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[9].ref-info.ref-volisspag.pagerange
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[9].ref-info.ref-volisspag.pagerange.@first
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[9].ref-info.ref-volisspag.pagerange.@last
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[9].ref-info.ref-authors
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[9].ref-info.ref-authors.author
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[9].ref-info.ref-authors.author[0].@seq
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[9].ref-info.ref-authors.author[0].ce:initials
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[9].ref-info.ref-authors.author[0].@_fa
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[9].ref-info.ref-authors.author[0].ce:surname
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[9].ref-info.ref-authors.author[0].ce:indexed-name
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[9].ref-info.ref-authors.author[1].@seq
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[9].ref-info.ref-authors.author[1].ce:initials
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[9].ref-info.ref-authors.author[1].@_fa
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[9].ref-info.ref-authors.author[1].ce:surname
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[9].ref-info.ref-authors.author[1].ce:indexed-name
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[9].ref-info.ref-authors.author[2].@seq
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[9].ref-info.ref-authors.author[2].ce:initials
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[9].ref-info.ref-authors.author[2].@_fa
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[9].ref-info.ref-authors.author[2].ce:surname
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[9].ref-info.ref-authors.author[2].ce:indexed-name
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[9].ref-info.ref-authors.et-al
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[9].ref-info.ref-sourcetitle
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[10].ref-fulltext
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[10].@id
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[10].ref-info
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[10].ref-info.ref-publicationyear
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[10].ref-info.ref-publicationyear.@first
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[10].ref-info.ref-title
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[10].ref-info.ref-title.ref-titletext
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[10].ref-info.refd-itemidlist
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[10].ref-info.refd-itemidlist.itemid
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[10].ref-info.refd-itemidlist.itemid.$
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[10].ref-info.refd-itemidlist.itemid.@idtype
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[10].ref-info.ref-volisspag
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[10].ref-info.ref-volisspag.voliss
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[10].ref-info.ref-volisspag.voliss.@volume
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[10].ref-info.ref-volisspag.pagerange
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[10].ref-info.ref-volisspag.pagerange.@first
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[10].ref-info.ref-authors
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[10].ref-info.ref-authors.author
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[10].ref-info.ref-authors.author[0].@seq
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[10].ref-info.ref-authors.author[0].ce:initials
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[10].ref-info.ref-authors.author[0].@_fa
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[10].ref-info.ref-authors.author[0].ce:surname
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[10].ref-info.ref-authors.author[0].ce:indexed-name
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[10].ref-info.ref-sourcetitle
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[11].ref-fulltext
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[11].@id
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[11].ref-info
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[11].ref-info.ref-website
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[11].ref-info.ref-website.ce:e-address
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[11].ref-info.ref-website.ce:e-address.$
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[11].ref-info.ref-website.ce:e-address.@type
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[11].ref-info.refd-itemidlist
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[11].ref-info.refd-itemidlist.itemid
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[11].ref-info.refd-itemidlist.itemid.$
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[11].ref-info.refd-itemidlist.itemid.@idtype
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[11].ref-info.ref-authors
# ...
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[73].ref-info.ref-authors.collaboration.ce:text
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[73].ref-info.ref-authors.collaboration.ce:indexed-name
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[73].ref-info.ref-sourcetitle
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[74].ref-fulltext
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[74].@id
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[74].ref-info
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[74].ref-info.ref-publicationyear
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[74].ref-info.ref-publicationyear.@first
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[74].ref-info.ref-title
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[74].ref-info.ref-title.ref-titletext
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[74].ref-info.refd-itemidlist
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[74].ref-info.refd-itemidlist.itemid
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[74].ref-info.refd-itemidlist.itemid.$
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[74].ref-info.refd-itemidlist.itemid.@idtype
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[74].ref-info.ref-volisspag
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[74].ref-info.ref-volisspag.voliss
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[74].ref-info.ref-volisspag.voliss.@volume
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[74].ref-info.ref-volisspag.voliss.@issue
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[74].ref-info.ref-volisspag.pagerange
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[74].ref-info.ref-volisspag.pagerange.@first
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[74].ref-info.ref-volisspag.pagerange.@last
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[74].ref-info.ref-authors
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[74].ref-info.ref-authors.author
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[74].ref-info.ref-authors.author[0].@seq
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[74].ref-info.ref-authors.author[0].ce:initials
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[74].ref-info.ref-authors.author[0].@_fa
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[74].ref-info.ref-authors.author[0].ce:surname
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[74].ref-info.ref-authors.author[0].ce:indexed-name
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[74].ref-info.ref-authors.author[1].@seq
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[74].ref-info.ref-authors.author[1].ce:initials
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[74].ref-info.ref-authors.author[1].@_fa
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[74].ref-info.ref-authors.author[1].ce:surname
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[74].ref-info.ref-authors.author[1].ce:indexed-name
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[74].ref-info.ref-sourcetitle
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[75].ref-fulltext
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[75].@id
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[75].ref-info
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[75].ref-info.ref-publicationyear
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[75].ref-info.ref-publicationyear.@first
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[75].ref-info.ref-title
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[75].ref-info.ref-title.ref-titletext
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[75].ref-info.refd-itemidlist
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[75].ref-info.refd-itemidlist.itemid
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[75].ref-info.refd-itemidlist.itemid.$
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[75].ref-info.refd-itemidlist.itemid.@idtype
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[75].ref-info.ref-volisspag
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[75].ref-info.ref-volisspag.voliss
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[75].ref-info.ref-volisspag.voliss.@volume
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[75].ref-info.ref-volisspag.voliss.@issue
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[75].ref-info.ref-volisspag.pagerange
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[75].ref-info.ref-volisspag.pagerange.@first
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[75].ref-info.ref-volisspag.pagerange.@last
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[75].ref-info.ref-authors
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[75].ref-info.ref-authors.author
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[75].ref-info.ref-authors.author[0].@seq
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[75].ref-info.ref-authors.author[0].ce:initials
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[75].ref-info.ref-authors.author[0].@_fa
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[75].ref-info.ref-authors.author[0].ce:surname
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[75].ref-info.ref-authors.author[0].ce:indexed-name
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[75].ref-info.ref-authors.author[1].@seq
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[75].ref-info.ref-authors.author[1].ce:initials
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[75].ref-info.ref-authors.author[1].@_fa
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[75].ref-info.ref-authors.author[1].ce:surname
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[75].ref-info.ref-authors.author[1].ce:indexed-name
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[75].ref-info.ref-authors.author[2].@seq
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[75].ref-info.ref-authors.author[2].ce:initials
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[75].ref-info.ref-authors.author[2].@_fa
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[75].ref-info.ref-authors.author[2].ce:surname
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[75].ref-info.ref-authors.author[2].ce:indexed-name
# abstracts-retrieval-response.item.bibrecord.tail.bibliography.reference[75].ref-info.ref-sourcetitle
# abstracts-retrieval-response.affiliation
# abstracts-retrieval-response.affiliation[0].affiliation-city
# abstracts-retrieval-response.affiliation[0].@id
# abstracts-retrieval-response.affiliation[0].affilname
# abstracts-retrieval-response.affiliation[0].@href
# abstracts-retrieval-response.affiliation[0].affiliation-country
# abstracts-retrieval-response.affiliation[1].affiliation-city
# abstracts-retrieval-response.affiliation[1].@id
# abstracts-retrieval-response.affiliation[1].affilname
# abstracts-retrieval-response.affiliation[1].@href
# abstracts-retrieval-response.affiliation[1].affiliation-country
# abstracts-retrieval-response.affiliation[2].affiliation-city
# abstracts-retrieval-response.affiliation[2].@id
# abstracts-retrieval-response.affiliation[2].affilname
# abstracts-retrieval-response.affiliation[2].@href
# abstracts-retrieval-response.affiliation[2].affiliation-country
# abstracts-retrieval-response.affiliation[3].affiliation-city
# abstracts-retrieval-response.affiliation[3].@id
# abstracts-retrieval-response.affiliation[3].affilname
# abstracts-retrieval-response.affiliation[3].@href
# abstracts-retrieval-response.affiliation[3].affiliation-country
# abstracts-retrieval-response.affiliation[4].affiliation-city
# abstracts-retrieval-response.affiliation[4].@id
# abstracts-retrieval-response.affiliation[4].affilname
# abstracts-retrieval-response.affiliation[4].@href
# abstracts-retrieval-response.affiliation[4].affiliation-country
# abstracts-retrieval-response.affiliation[5].affiliation-city
# abstracts-retrieval-response.affiliation[5].@id
# abstracts-retrieval-response.affiliation[5].affilname
# abstracts-retrieval-response.affiliation[5].@href
# abstracts-retrieval-response.affiliation[5].affiliation-country
# abstracts-retrieval-response.coredata
# abstracts-retrieval-response.coredata.srctype
# abstracts-retrieval-response.coredata.eid
# abstracts-retrieval-response.coredata.prism:coverDate
# abstracts-retrieval-response.coredata.prism:aggregationType
# abstracts-retrieval-response.coredata.prism:url
# abstracts-retrieval-response.coredata.subtypeDescription
# abstracts-retrieval-response.coredata.dc:creator
# abstracts-retrieval-response.coredata.dc:creator.author
# abstracts-retrieval-response.coredata.dc:creator.author[0].ce:given-name
# abstracts-retrieval-response.coredata.dc:creator.author[0].preferred-name
# abstracts-retrieval-response.coredata.dc:creator.author[0].preferred-name.ce:given-name
# abstracts-retrieval-response.coredata.dc:creator.author[0].preferred-name.ce:initials
# abstracts-retrieval-response.coredata.dc:creator.author[0].preferred-name.ce:surname
# abstracts-retrieval-response.coredata.dc:creator.author[0].preferred-name.ce:indexed-name
# abstracts-retrieval-response.coredata.dc:creator.author[0].@seq
# abstracts-retrieval-response.coredata.dc:creator.author[0].ce:initials
# abstracts-retrieval-response.coredata.dc:creator.author[0].@_fa
# abstracts-retrieval-response.coredata.dc:creator.author[0].affiliation
# abstracts-retrieval-response.coredata.dc:creator.author[0].affiliation[0].@id
# abstracts-retrieval-response.coredata.dc:creator.author[0].affiliation[0].@href
# abstracts-retrieval-response.coredata.dc:creator.author[0].affiliation[1].@id
# abstracts-retrieval-response.coredata.dc:creator.author[0].affiliation[1].@href
# abstracts-retrieval-response.coredata.dc:creator.author[0].affiliation[2].@id
# abstracts-retrieval-response.coredata.dc:creator.author[0].affiliation[2].@href
# abstracts-retrieval-response.coredata.dc:creator.author[0].ce:degrees
# abstracts-retrieval-response.coredata.dc:creator.author[0].ce:surname
# abstracts-retrieval-response.coredata.dc:creator.author[0].@auid
# abstracts-retrieval-response.coredata.dc:creator.author[0].author-url
# abstracts-retrieval-response.coredata.dc:creator.author[0].ce:indexed-name
# abstracts-retrieval-response.coredata.link
# abstracts-retrieval-response.coredata.link[0].@_fa
# abstracts-retrieval-response.coredata.link[0].@rel
# abstracts-retrieval-response.coredata.link[0].@href
# abstracts-retrieval-response.coredata.link[1].@_fa
# abstracts-retrieval-response.coredata.link[1].@rel
# abstracts-retrieval-response.coredata.link[1].@href
# abstracts-retrieval-response.coredata.link[2].@_fa
# abstracts-retrieval-response.coredata.link[2].@rel
# abstracts-retrieval-response.coredata.link[2].@href
# abstracts-retrieval-response.coredata.prism:isbn
# abstracts-retrieval-response.coredata.prism:isbn[0].$
# abstracts-retrieval-response.coredata.prism:isbn[1].$
# abstracts-retrieval-response.coredata.prism:publicationName
# abstracts-retrieval-response.coredata.source-id
# abstracts-retrieval-response.coredata.citedby-count
# abstracts-retrieval-response.coredata.subtype
# abstracts-retrieval-response.coredata.prism:pageRange
# abstracts-retrieval-response.coredata.dc:title
# abstracts-retrieval-response.coredata.prism:endingPage
# abstracts-retrieval-response.coredata.openaccess
# abstracts-retrieval-response.coredata.openaccessFlag
# abstracts-retrieval-response.coredata.prism:doi
# abstracts-retrieval-response.coredata.prism:startingPage
# abstracts-retrieval-response.coredata.dc:identifier
# abstracts-retrieval-response.coredata.dc:publisher
# abstracts-retrieval-response.idxterms
# abstracts-retrieval-response.language
# abstracts-retrieval-response.language.@xml:lang
# abstracts-retrieval-response.authkeywords
# abstracts-retrieval-response.subject-areas
# abstracts-retrieval-response.subject-areas.subject-area
# abstracts-retrieval-response.subject-areas.subject-area[0].@_fa
# abstracts-retrieval-response.subject-areas.subject-area[0].$
# abstracts-retrieval-response.subject-areas.subject-area[0].@code
# abstracts-retrieval-response.subject-areas.subject-area[0].@abbrev
# abstracts-retrieval-response.authors
# abstracts-retrieval-response.authors.author
# abstracts-retrieval-response.authors.author[0].ce:given-name
# abstracts-retrieval-response.authors.author[0].preferred-name
# abstracts-retrieval-response.authors.author[0].preferred-name.ce:given-name
# abstracts-retrieval-response.authors.author[0].preferred-name.ce:initials
# abstracts-retrieval-response.authors.author[0].preferred-name.ce:surname
# abstracts-retrieval-response.authors.author[0].preferred-name.ce:indexed-name
# abstracts-retrieval-response.authors.author[0].@seq
# abstracts-retrieval-response.authors.author[0].ce:initials
# abstracts-retrieval-response.authors.author[0].@_fa
# abstracts-retrieval-response.authors.author[0].affiliation
# abstracts-retrieval-response.authors.author[0].affiliation[0].@id
# abstracts-retrieval-response.authors.author[0].affiliation[0].@href
# abstracts-retrieval-response.authors.author[0].affiliation[1].@id
# abstracts-retrieval-response.authors.author[0].affiliation[1].@href
# abstracts-retrieval-response.authors.author[0].affiliation[2].@id
# abstracts-retrieval-response.authors.author[0].affiliation[2].@href
# abstracts-retrieval-response.authors.author[0].ce:degrees
# abstracts-retrieval-response.authors.author[0].ce:surname
# abstracts-retrieval-response.authors.author[0].@auid
# abstracts-retrieval-response.authors.author[0].author-url
# abstracts-retrieval-response.authors.author[0].ce:indexed-name
# abstracts-retrieval-response.authors.author[1].ce:given-name
# abstracts-retrieval-response.authors.author[1].preferred-name
# abstracts-retrieval-response.authors.author[1].preferred-name.ce:given-name
# abstracts-retrieval-response.authors.author[1].preferred-name.ce:initials
# abstracts-retrieval-response.authors.author[1].preferred-name.ce:surname
# abstracts-retrieval-response.authors.author[1].preferred-name.ce:indexed-name
# abstracts-retrieval-response.authors.author[1].@seq
# abstracts-retrieval-response.authors.author[1].ce:initials
# abstracts-retrieval-response.authors.author[1].@_fa
# abstracts-retrieval-response.authors.author[1].affiliation
# abstracts-retrieval-response.authors.author[1].affiliation[0].@id
# abstracts-retrieval-response.authors.author[1].affiliation[0].@href
# abstracts-retrieval-response.authors.author[1].affiliation[1].@id
# abstracts-retrieval-response.authors.author[1].affiliation[1].@href
# abstracts-retrieval-response.authors.author[1].affiliation[2].@id
# abstracts-retrieval-response.authors.author[1].affiliation[2].@href
# abstracts-retrieval-response.authors.author[1].ce:degrees
# abstracts-retrieval-response.authors.author[1].ce:surname
# abstracts-retrieval-response.authors.author[1].@auid
# abstracts-retrieval-response.authors.author[1].author-url
# abstracts-retrieval-response.authors.author[1].ce:indexed-name

# %%
df = pd.json_normalize(data, sep='_')

print(len(df.columns))
print(df.columns)
# Out:
# 83
# Index(['abstracts-retrieval-response_item_ait:process-info_ait:status_@state',
#        'abstracts-retrieval-response_item_ait:process-info_ait:status_@type',
#        'abstracts-retrieval-response_item_ait:process-info_ait:status_@stage',
#        'abstracts-retrieval-response_item_ait:process-info_ait:date-delivered_@day',
#        'abstracts-retrieval-response_item_ait:process-info_ait:date-delivered_@timestamp',
#        'abstracts-retrieval-response_item_ait:process-info_ait:date-delivered_@year',
#        'abstracts-retrieval-response_item_ait:process-info_ait:date-delivered_@month',
#        'abstracts-retrieval-response_item_ait:process-info_ait:date-sort_@day',
#        'abstracts-retrieval-response_item_ait:process-info_ait:date-sort_@year',
#        'abstracts-retrieval-response_item_ait:process-info_ait:date-sort_@month',
#        'abstracts-retrieval-response_item_bibrecord_head_author-group',
#        'abstracts-retrieval-response_item_bibrecord_head_citation-title',
#        'abstracts-retrieval-response_item_bibrecord_head_abstracts',
#        'abstracts-retrieval-response_item_bibrecord_head_correspondence_affiliation_country',
#        'abstracts-retrieval-response_item_bibrecord_head_correspondence_affiliation_@country',
#        'abstracts-retrieval-response_item_bibrecord_head_correspondence_affiliation_city',
#        'abstracts-retrieval-response_item_bibrecord_head_correspondence_affiliation_organization',
#        'abstracts-retrieval-response_item_bibrecord_head_correspondence_person_ce:given-name',
#        'abstracts-retrieval-response_item_bibrecord_head_correspondence_person_ce:initials',
#        'abstracts-retrieval-response_item_bibrecord_head_correspondence_person_ce:degrees',
#        'abstracts-retrieval-response_item_bibrecord_head_correspondence_person_ce:surname',
#        'abstracts-retrieval-response_item_bibrecord_head_correspondence_person_ce:indexed-name',
#        'abstracts-retrieval-response_item_bibrecord_head_citation-info_citation-type_@code',
#        'abstracts-retrieval-response_item_bibrecord_head_citation-info_citation-language_@language',
#        'abstracts-retrieval-response_item_bibrecord_head_citation-info_citation-language_@xml:lang',
#        'abstracts-retrieval-response_item_bibrecord_head_source_sourcetitle-abbrev',
#        'abstracts-retrieval-response_item_bibrecord_head_source_website_ce:e-address_$',
#        'abstracts-retrieval-response_item_bibrecord_head_source_website_ce:e-address_@type',
#        'abstracts-retrieval-response_item_bibrecord_head_source_@country',
#        'abstracts-retrieval-response_item_bibrecord_head_source_translated-sourcetitle_@xml:lang',
#        'abstracts-retrieval-response_item_bibrecord_head_source_volisspag_pagerange_@first',
#        'abstracts-retrieval-response_item_bibrecord_head_source_volisspag_pagerange_@last',
#        'abstracts-retrieval-response_item_bibrecord_head_source_@type',
#        'abstracts-retrieval-response_item_bibrecord_head_source_publicationyear_@first',
#        'abstracts-retrieval-response_item_bibrecord_head_source_isbn',
#        'abstracts-retrieval-response_item_bibrecord_head_source_publisher_publishername',
#        'abstracts-retrieval-response_item_bibrecord_head_source_sourcetitle',
#        'abstracts-retrieval-response_item_bibrecord_head_source_@srcid',
#        'abstracts-retrieval-response_item_bibrecord_head_source_publicationdate_month',
#        'abstracts-retrieval-response_item_bibrecord_head_source_publicationdate_year',
#        'abstracts-retrieval-response_item_bibrecord_head_source_publicationdate_date-text_@xfab-added',
#        'abstracts-retrieval-response_item_bibrecord_head_source_publicationdate_date-text_$',
#        'abstracts-retrieval-response_item_bibrecord_head_source_publicationdate_day',
#        'abstracts-retrieval-response_item_bibrecord_head_enhancement_classificationgroup_classifications',
#        'abstracts-retrieval-response_item_bibrecord_item-info_copyright_$',
#        'abstracts-retrieval-response_item_bibrecord_item-info_copyright_@type',
#        'abstracts-retrieval-response_item_bibrecord_item-info_dbcollection',
#        'abstracts-retrieval-response_item_bibrecord_item-info_history_date-created_@day',
#        'abstracts-retrieval-response_item_bibrecord_item-info_history_date-created_@timestamp',
#        'abstracts-retrieval-response_item_bibrecord_item-info_history_date-created_@year',
#        'abstracts-retrieval-response_item_bibrecord_item-info_history_date-created_@month',
#        'abstracts-retrieval-response_item_bibrecord_item-info_itemidlist_itemid',
#        'abstracts-retrieval-response_item_bibrecord_item-info_itemidlist_ce:doi',
#        'abstracts-retrieval-response_item_bibrecord_tail_bibliography_@refcount',
#        'abstracts-retrieval-response_item_bibrecord_tail_bibliography_reference',
#        'abstracts-retrieval-response_affiliation',
#        'abstracts-retrieval-response_coredata_srctype',
#        'abstracts-retrieval-response_coredata_eid',
#        'abstracts-retrieval-response_coredata_prism:coverDate',
#        'abstracts-retrieval-response_coredata_prism:aggregationType',
#        'abstracts-retrieval-response_coredata_prism:url',
#        'abstracts-retrieval-response_coredata_subtypeDescription',
#        'abstracts-retrieval-response_coredata_dc:creator_author',
#        'abstracts-retrieval-response_coredata_link',
#        'abstracts-retrieval-response_coredata_prism:isbn',
#        'abstracts-retrieval-response_coredata_prism:publicationName',
#        'abstracts-retrieval-response_coredata_source-id',
#        'abstracts-retrieval-response_coredata_citedby-count',
#        'abstracts-retrieval-response_coredata_subtype',
#        'abstracts-retrieval-response_coredata_prism:pageRange',
#        'abstracts-retrieval-response_coredata_dc:title',
#        'abstracts-retrieval-response_coredata_prism:endingPage',
#        'abstracts-retrieval-response_coredata_openaccess',
#        'abstracts-retrieval-response_coredata_openaccessFlag',
#        'abstracts-retrieval-response_coredata_prism:doi',
#        'abstracts-retrieval-response_coredata_prism:startingPage',
#        'abstracts-retrieval-response_coredata_dc:identifier',
#        'abstracts-retrieval-response_coredata_dc:publisher',
#        'abstracts-retrieval-response_idxterms',
#        'abstracts-retrieval-response_language_@xml:lang',
#        'abstracts-retrieval-response_authkeywords',
#        'abstracts-retrieval-response_subject-areas_subject-area',
#        'abstracts-retrieval-response_authors_author'],
#       dtype='object')

# %%
print(df['abstracts-retrieval-response_affiliation'])
# Out:
# 0    [{'affiliation-city': 'Stanford', '@id': '6003...
# Name: abstracts-retrieval-response_affiliation, dtype: object

# %%
new_columns = []

for column in df.columns:
    if column.startswith('abstracts-retrieval-response_item_bibrecord'):
        continue
    new_columns.append(column)

new_df = df[new_columns].copy()

# %%
print(len(new_df.columns))
new_df.to_csv('201800000.csv', index=False)  # Save the DataFrame to a CSV file
# Out:
# 38
